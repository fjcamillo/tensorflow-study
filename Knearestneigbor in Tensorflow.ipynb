# %%
import numpy as np
import tensorflow as tf

#import the mnist data set
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('/tmp/data/',one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
x_train, y_train = mnist.train.next_batch(5000)
x_test, y_test = mnist.test.next_batch(2000)

#will hold all pixels of the data set
X = tf.placeholder('float', [None, 784])

#holds ???
y = tf.placeholder('float', [784])

#Get the L1 Distance --> ??
# |x_train + (-x_test)|
#reduction_sum --> reduceses the dimensions by adding the data according to the given indices parameter
distance = tf.reduce_sum(tf.abs(tf.add(X, tf.neg(y))), reduction_indices=1)
pred = tf.arg_min(distance, 0)

accuracy = 0

init = tf.initialize_all_variables()

with tf.Session() as sess:
    sess.run(init)
    for i in range(len(x_test)):
        nn_index = sess.run(pred, feed_dict={X: x_train, y: x_test[i, :]})
        print nn_index ," my print"
        print "Test ", i, " Prediction: ", np.argmax(y_train[nn_index]), "True Class: ", np.argmax(y_test[i])
        
        if np.argmax(y_train[nn_index]) == np.argmax(y_test[i]):
            accuracy += 1./len(x_test)
        print "Done"
        print "Accuracy: ", accuracy
# Out:
# 3844  my print
# Test  0  Prediction:  8 True Class:  8
# Done
# Accuracy:  0.0005
# 2650  my print
# Test  1  Prediction:  1 True Class:  1
# Done
# Accuracy:  0.001
# 1602  my print
# Test  2  Prediction:  5 True Class:  8
# Done
# Accuracy:  0.001
# 4075  my print
# Test  3  Prediction:  0 True Class:  0
# Done
# Accuracy:  0.0015
# 1880  my print
# Test  4  Prediction:  9 True Class:  3
# Done
# Accuracy:  0.0015
# 3037  my print
# Test  5  Prediction:  3 True Class:  3
# Done
# Accuracy:  0.002
# 2508  my print
# Test  6  Prediction:  7 True Class:  7
# Done
# Accuracy:  0.0025
# 2925  my print
# Test  7  Prediction:  2 True Class:  2
# Done
# Accuracy:  0.003
# 114  my print
# Test  8  Prediction:  5 True Class:  3
# Done
# Accuracy:  0.003
# 993  my print
# Test  9  Prediction:  6 True Class:  6
# Done
# Accuracy:  0.0035
# 785  my print
# Test  10  Prediction:  2 True Class:  2
# Done
# Accuracy:  0.004
# 2978  my print
# Test  11  Prediction:  1 True Class:  1
# Done
# ...

# %%
#small sample on reduce_sum

#3x2 --> 2D
p = [[1,1,3], 
     [1,1,1]]

#3x2x3 --> 3D
pp = [
    [[1,2,3],[4,5,6]],
    [[1,2,3],[4,5,6]],
    [[1,2,3],[4,5,6]]
]

with tf.Session() as sess:
    print(sess.run(tf.reduce_sum(pp, reduction_indices=2)))
    #reduction_indices = # of dimension the tensor must be reduced to.
# Out:
# [[ 6 15]
#  [ 6 15]
#  [ 6 15]]
